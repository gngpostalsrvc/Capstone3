# %% [markdown]
# # Capstone 3 -  Preprocessing

# %%
#import the necessary packages
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#load the data
df = pd.read_csv('labeled_verses_vectorized.csv', index_col='Verse')

df.head()
# Out:
#                             Stage         0         1         2         3  \
# Verse
# Gen 49:2  Archaic Biblical Hebrew  0.464157 -0.494222  0.697796 -2.002240
# Gen 49:3  Archaic Biblical Hebrew  0.438628 -1.068966  0.060051 -0.477385
# Gen 49:4  Archaic Biblical Hebrew  0.680925 -0.565372 -0.652052  0.361750
# Gen 49:5  Archaic Biblical Hebrew  0.813855 -0.299782  0.093762 -0.309304
# Gen 49:6  Archaic Biblical Hebrew  0.573014 -0.111786 -0.634491  0.814129
#
#                  4         5         6         7         8  ...       758  \
# Verse                                                       ...
# Gen 49:2 -0.481948 -0.009591 -1.046462 -0.491135 -0.549707  ...  0.359742
# Gen 49:3 -1.226976 -1.797044 -0.415015  0.217263  0.254980  ...  0.700247
# Gen 49:4 -1.093759 -1.675976 -0.151216 -1.094890  0.015146  ...  0.302197
# Gen 49:5 -1.499361 -1.831533 -0.121176 -0.892737  0.038607  ... -0.491955
# Gen 49:6 -0.737395 -1.424042  0.092141 -0.991415  0.701928  ...  0.036195
#
#                759       760       761       762       763       764  \
# Verse
# Gen 49:2 -0.149865  0.519176 -0.539552 -0.833575 -0.973837  0.454395
# Gen 49:3 -0.207136  0.079080 -0.241488 -0.290693  0.273426  0.195876
# Gen 49:4  0.198747  0.199398  0.874569 -0.498688  0.930374 -0.172042
# Gen 49:5 -0.178500  0.479455  0.930159 -0.282761  1.199329  0.527644
# Gen 49:6 -0.794484  0.272742  0.718796 -0.528398  1.133588 -0.160358
#
#                765       766       767
# Verse
# Gen 49:2  0.121786  0.292993  1.242339
# Gen 49:3  1.160682 -0.293586  1.955988
# Gen 49:4  1.351107  0.905352  1.003636
# Gen 49:5  1.093994 -0.072787  2.475052
# Gen 49:6  0.229029  0.404836  0.819664
#
# [5 rows x 769 columns]

# %%
X = df.drop(columns='Stage')
y = df[['Stage']]

# %%
y =  pd.get_dummies(y, drop_first=True)

# %%
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
X_train.to_csv('X_train.csv')

# %%
y_train.to_csv('y_train.csv')

# %%
X_test.to_csv('X_test.csv')

# %%
y_test.to_csv('y_test.csv')
